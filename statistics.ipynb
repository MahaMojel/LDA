# %%
import pandas as pd

# %%
df = pd.read_csv('../input/converted/df_final.csv')
df.head()
# Out:
#    Unnamed: 0  Id  PostTypeId             CreationDate  Score  ViewCount  \
# 0           0   5           1  2014-05-13T23:58:30.457      9      820.0
# 1           1   7           1  2014-05-14T00:11:06.457      4      462.0
# 2           2   9           2  2014-05-14T00:36:31.077      5        NaN
# 3           3  10           2  2014-05-14T00:53:43.273     13        NaN
# 4           4  14           1  2014-05-14T01:25:59.677     25     1876.0
#
#                                                 Body  OwnerUserId  \
# 0  I always interested machine learning I figure ...          5.0
# 1  As researcher instructor I looking open source...         36.0
# 2  Not sure fits scope SE stab answer anyway With...         51.0
# 3  One book freely available The Elements Statist...         22.0
# 4  I sure data science discussed forum several sy...         66.0
#
#           LastActivityDate                                              Title  \
# ...

# %%
df_0 = df[df['Dominant_Topic'] == 0]
df_1 = df[df['Dominant_Topic'] == 1]
df_2 = df[df['Dominant_Topic'] == 2]
df_3 = df[df['Dominant_Topic'] == 3]
df_4 = df[df['Dominant_Topic'] == 4]
df_5 = df[df['Dominant_Topic'] == 5]

# %%
len(df_0),len(df_1),len(df_2),len(df_3),len(df_4),len(df_5)
# Out:
# (5851, 5251, 747, 6293, 2603, 48194)

# %%
print(df_0.ViewCount.describe())
# Out:
# count      2304.000000
# mean       1875.890191
# std        8995.812221
# min           4.000000
# 25%          38.000000
# 50%         131.500000
# 75%         684.000000
# max      268099.000000
# Name: ViewCount, dtype: float64

# %%
print(df_1.ViewCount.describe())
# Out:
# count      2159.000000
# mean       3725.635479
# std       14786.715979
# min           3.000000
# 25%          58.000000
# 50%         297.000000
# 75%        1737.500000
# max      308042.000000
# Name: ViewCount, dtype: float64

# %%
print(df_2.ViewCount.describe())
# Out:
# count      365.000000
# mean      2859.934247
# std       7556.841423
# min          7.000000
# 25%         52.000000
# 50%        350.000000
# 75%       2048.000000
# max      67213.000000
# Name: ViewCount, dtype: float64

# %%
print(df_3.ViewCount.describe())
# Out:
# count      3430.000000
# mean       1636.130904
# std        7085.272597
# min           3.000000
# 25%          46.000000
# 50%         174.500000
# 75%         872.500000
# max      249602.000000
# Name: ViewCount, dtype: float64

# %%
print(df_4.ViewCount.describe())
# Out:
# count      1408.000000
# mean       1884.705966
# std        9859.452892
# min           3.000000
# 25%          38.000000
# 50%         113.000000
# 75%         616.250000
# max      191654.000000
# Name: ViewCount, dtype: float64

# %%
print(df_5.ViewCount.describe())
# Out:
# count     22831.000000
# mean       1534.464456
# std        8804.032749
# min           2.000000
# 25%          40.000000
# 50%         123.000000
# 75%         605.500000
# max      359046.000000
# Name: ViewCount, dtype: float64

# %%
print(df_0.AnswerCount.describe())
# Out:
# count    2304.000000
# mean        1.071181
# std         1.048607
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max        17.000000
# Name: AnswerCount, dtype: float64

# %%
print(df_1.AnswerCount.describe())
# Out:
# count    2159.000000
# mean        1.171376
# std         0.994561
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max        10.000000
# Name: AnswerCount, dtype: float64

# %%
print(df_2.AnswerCount.describe())
# Out:
# count    365.000000
# mean       0.997260
# std        0.976365
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        6.000000
# Name: AnswerCount, dtype: float64

# %%
print(df_3.AnswerCount.describe())
# Out:
# count    3430.000000
# mean        0.948688
# std         0.864546
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max        11.000000
# Name: AnswerCount, dtype: float64

# %%
print(df_4.AnswerCount.describe())
# Out:
# count    1408.000000
# mean        1.242188
# std         1.315377
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max        14.000000
# Name: AnswerCount, dtype: float64

# %%
print(df_5.AnswerCount.describe())
# Out:
# count    22831.000000
# mean         1.120582
# std          1.057709
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max         35.000000
# Name: AnswerCount, dtype: float64

# %%
print(df_0.Score.describe())
# Out:
# count    5851.000000
# mean        2.138438
# std         7.014148
# min        -3.000000
# 25%         0.000000
# 50%         1.000000
# 75%         2.000000
# max       284.000000
# Name: Score, dtype: float64

# %%
print(df_1.Score.describe())
# Out:
# count    5251.000000
# mean        1.871643
# std         5.291781
# min        -6.000000
# 25%         0.000000
# 50%         1.000000
# 75%         2.000000
# max       219.000000
# Name: Score, dtype: float64

# %%
print(df_2.Score.describe())
# Out:
# count    747.000000
# mean       1.638554
# std        3.409970
# min       -3.000000
# 25%        0.000000
# 50%        1.000000
# 75%        2.000000
# max       41.000000
# Name: Score, dtype: float64

# %%
print(df_3.Score.describe())
# Out:
# count    6293.000000
# mean        2.040521
# std         6.815835
# min        -3.000000
# 25%         0.000000
# 50%         1.000000
# 75%         2.000000
# max       266.000000
# Name: Score, dtype: float64

# %%
print(df_4.Score.describe())
# Out:
# count    2603.000000
# mean        1.956589
# std         4.508600
# min        -5.000000
# 25%         0.000000
# 50%         1.000000
# 75%         2.000000
# max        79.000000
# Name: Score, dtype: float64

# %%
print(df_5.Score.describe())
# Out:
# count    48194.000000
# mean         2.073370
# std          6.127828
# min         -6.000000
# 25%          0.000000
# 50%          1.000000
# 75%          2.000000
# max        400.000000
# Name: Score, dtype: float64

# %%
print(df_0.FavoriteCount.describe())
# Out:
# count    582.000000
# mean       2.865979
# std        8.309581
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max      127.000000
# Name: FavoriteCount, dtype: float64

# %%
print(df_1.FavoriteCount.describe())
# Out:
# count    457.000000
# mean       2.306346
# std        3.437765
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max       32.000000
# Name: FavoriteCount, dtype: float64

# %%
print(df_2.FavoriteCount.describe())
# Out:
# count    80.000000
# mean      2.200000
# std       1.925183
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       3.000000
# max      10.000000
# Name: FavoriteCount, dtype: float64

# %%
print(df_3.FavoriteCount.describe())
# Out:
# count    867.000000
# mean       2.312572
# std        7.474382
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max      181.000000
# Name: FavoriteCount, dtype: float64

# %%
print(df_4.FavoriteCount.describe())
# Out:
# count    396.000000
# mean       2.704545
# std        4.986166
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max       49.000000
# Name: FavoriteCount, dtype: float64

# %%
print(df_5.FavoriteCount.describe())
# Out:
# count    6070.000000
# mean        2.666722
# std         7.571386
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max       196.000000
# Name: FavoriteCount, dtype: float64

# %%
print(df_0.AcceptedAnswerId.describe())
# Out:
# count       809.000000
# mean      56277.746601
# std       28819.571125
# min          46.000000
# 25%       31331.000000
# 50%       56309.000000
# 75%       80540.000000
# max      108602.000000
# Name: AcceptedAnswerId, dtype: float64

# %%
print(df_1.AcceptedAnswerId.describe())
# Out:
# count       889.000000
# mean      52707.031496
# std       28589.561259
# min         535.000000
# 25%       29382.000000
# 50%       51398.000000
# 75%       74424.000000
# max      108680.000000
# Name: AcceptedAnswerId, dtype: float64

# %%
print(df_2.AcceptedAnswerId.describe())
# Out:
# count       102.000000
# mean      46484.588235
# std       29184.062674
# min         797.000000
# 25%       23725.500000
# 50%       42542.500000
# 75%       66107.250000
# max      104740.000000
# Name: AcceptedAnswerId, dtype: float64

# %%
print(df_3.AcceptedAnswerId.describe())
# Out:
# count      1211.000000
# mean      57363.551610
# std       27381.331749
# min          97.000000
# 25%       34115.500000
# 50%       56055.000000
# 75%       80905.500000
# max      108384.000000
# Name: AcceptedAnswerId, dtype: float64

# %%
print(df_4.AcceptedAnswerId.describe())
# Out:
# count       423.000000
# mean      42606.047281
# std       31367.191562
# min          29.000000
# 25%       14434.000000
# 50%       38229.000000
# 75%       67022.000000
# max      108501.000000
# Name: AcceptedAnswerId, dtype: float64

# %%
print(df_5.AcceptedAnswerId.describe())
# Out:
# count      7312.000000
# mean      49557.695842
# std       30108.940076
# min          10.000000
# 25%       23892.000000
# 50%       46843.000000
# 75%       74855.250000
# max      108759.000000
# Name: AcceptedAnswerId, dtype: float64
